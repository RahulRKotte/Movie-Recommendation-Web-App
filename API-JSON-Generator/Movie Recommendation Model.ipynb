# %%
import numpy as np
import pandas as pd
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
movies_data = pd.read_csv('movies_final.csv')

# %%
movies_data.head()
# Out:
#    Unnamed: 0  index                                              Title  \
# 0           0      0                       Aquaman and the Lost Kingdom
# 1           1      1  The Hunger Games: The Ballad of Songbirds & Sn...
# 2           2      2                                    The Family Plan
# 3           3      3                                              Wonka
# 4           4      4                    Chicken Run: Dawn of the Nugget
#
#                                              Details
# 0  Aquaman and the Lost Kingdom Action Adventure ...
# 1  The Hunger Games: The Ballad of Songbirds & Sn...
# 2  The Family Plan Action Comedy  Mark Wahlberg M...
# 3  Wonka Comedy Family Fantasy Every good thing i...
# 4  Chicken Run: Dawn of the Nugget Animation Adve...

# %%
movies_data.shape
# Out:
# (14490, 4)

# %%
movies_data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
movies_data
# Out:
#        index                                              Title  \
# 0          0                       Aquaman and the Lost Kingdom
# 1          1  The Hunger Games: The Ballad of Songbirds & Sn...
# 2          2                                    The Family Plan
# 3          3                                              Wonka
# 4          4                    Chicken Run: Dawn of the Nugget
# ...      ...                                                ...
# 14485  14485                                        El Mariachi
# 14486  14486                                          Newlyweds
# 14487  14487                          Signed, Sealed, Delivered
# 14488  14488                                   Shanghai Calling
# 14489  14489                                  My Date with Drew
#
#                                                  Details
# 0      Aquaman and the Lost Kingdom Action Adventure ...
# 1      The Hunger Games: The Ballad of Songbirds & Sn...
# 2      The Family Plan Action Comedy  Mark Wahlberg M...
# 3      Wonka Comedy Family Fantasy Every good thing i...
# 4      Chicken Run: Dawn of the Nugget Animation Adve...
# ...                                                  ...
# 14485  El Mariachi Action Crime Thriller united state...
# 14486  Newlyweds Comedy Romance  A newlywed couple's ...
# 14487  Signed, Sealed, Delivered Comedy Drama Romance...
# 14488  Shanghai Calling   A New Yorker in Shanghai Da...
# 14489  My Date with Drew Documentary obsession camcor...
#
# [14490 rows x 3 columns]

# %%
combined_features = movies_data['Details']

# %%
print(combined_features)
# Out:
# 0        Aquaman and the Lost Kingdom Action Adventure ...
# 1        The Hunger Games: The Ballad of Songbirds & Sn...
# 2        The Family Plan Action Comedy  Mark Wahlberg M...
# 3        Wonka Comedy Family Fantasy Every good thing i...
# 4        Chicken Run: Dawn of the Nugget Animation Adve...
#                                ...
# 14485    El Mariachi Action Crime Thriller united state...
# 14486    Newlyweds Comedy Romance  A newlywed couple's ...
# 14487    Signed, Sealed, Delivered Comedy Drama Romance...
# 14488    Shanghai Calling   A New Yorker in Shanghai Da...
# 14489    My Date with Drew Documentary obsession camcor...
# Name: Details, Length: 14490, dtype: object

# %%
vectorizer = TfidfVectorizer()
feature_vectors = vectorizer.fit_transform(combined_features)

# %%
similarity = cosine_similarity(feature_vectors)

# %%
movie_name = input('Enter your favourite movie name - ')
# Out:
# Enter your favourite movie name - RRR

# %%
list_of_all_titles = movies_data['Title'].tolist()
print(list_of_all_titles)
# Out:
# ['Aquaman and the Lost Kingdom', 'The Hunger Games: The Ballad of Songbirds & Snakes', 'The Family Plan', 'Wonka', 'Chicken Run: Dawn of the Nugget', 'Oppenheimer', 'Trolls Band Together', 'Freelance', 'Killers of the Flower Moon', 'The Jester', 'Leave the World Behind', 'Megaboa', 'Leo', "Five Nights at Freddy's", 'Thanksgiving', 'Fast X', 'Silent Night', 'The Creator', 'Expend4bles', 'Barbie', 'Aquaman', 'How the Grinch Stole Christmas', 'The Super Mario Bros. Movie', 'Rebel Moon - Part One: A Child of Fire', 'The Grinch', 'Transformers: Rise of the Beasts', 'Good Boy', 'Mission: Impossible - Dead Reckoning Part One', 'Migration', 'Shrapnel', 'Godzilla Minus One', 'Krampus', 'Escaping Paradise', 'The Marvels', 'Avatar: The Way of Water', 'Elemental', 'The Dark Kingdom', 'Reign of Chaos', 'Christmas Bloody Christmas', 'Spider-Man: Across the Spider-Verse', 'Meg 2: The Trench', 'The Advent Calendar', 'The Equalizer 3', 'Wish', 'A Man of Reason', 'Spider-Man: No Way Home', 'Guimoon: The Lightless Door', 'PAW Patrol: The Mighty Movie', 'John Wick: Chapter 4', 'Gran Turismo', 'Galaxy Games', 'My Fault', 'Fast Charlie', 'Rumble Through the Dark', 'Shockwave: Countdown to Disaster', 'Mount Adams', 'Aquaman: Heroines of Atlantis', 'Blue Beetle', 'Finestkind', 'Puss in Boots: The Last Wish', 'Come Out Fighting', 'Indiana Jones and the Dial of Destiny', 'The Flash', 'Saw X', 'Muchachos, la película de la gente', 'Charlie and the Chocolate Factory', 'Kung Fu Panda', 'Home Alone 2: Lost in New York', 'Napoleon', 'Retribution', 'The Nun II', 'The Collective', 'Heroic', 'Maestro', 'Guardians of the Galaxy Vol. 3', "Harry Potter and the Philosopher's Stone", 'TAYLOR SWIFT | THE ERAS TOUR', 'The Hunger Games: Mockingjay - Part 1', 'Kung Fu Panda 2', 'Digimon Adventure 02: The Beginning', 'Kung Fu Panda 3', 'Sobreviviendo mis XV', 'After Everything', 'The Little Mermaid', 'Kung Fu Panda 4', 'Dragon Ball: Mystical Adventure', 'Candy Cane Lane', 'Merry Little Batman', 'Princess Khutulun', 'The Exorcist: Believer', 'Inferno', 'Wifelike', 'Mavka: The Forest Song', 'Psycho-Pass: Providence', 'Talk to Me', 'The Bad Guys: A Very Bad Holiday', 'A Tale of Two Guns', 'Avengers: Infinity War', 'Nowhere', 'Willy Wonka & the Chocolate Factory', 'Teenage Mutant Ninja Turtles: Mutant Mayhem', 'Percy Jackson & the Olympians: The Lightning Thief', 'The Feast of Amrita', 'Sound of Freedom', 'Inside Out', 'Interstellar', 'The Immortal Wars: Rebirth', 'Sonic the Hedgehog 2', 'Black Adam', 'Uri: The Surgical Strike', 'Mousa', 'Agent Jade Black', 'Miraculous: Ladybug & Cat Noir, The Movie', 'Rushed', 'Hypnotic', 'Jawan', 'The Polar Express', 'Godzilla vs. Kong', 'Harry Potter and the Chamber of Secrets', '2025: Blood, White & Blue', 'The Godfather', 'Muzzle', 'Extraction Point', 'Black Panther: Wakanda Forever', 'Hell House LLC Origins: The Carmichael Manor', 'Encanto', 'Diary of a Wimpy Kid Christmas: Cabin Fever', 'The Hunger Games: Catching Fire', 'The Lord of the Rings: The Return of the King', 'NAGA', 'Saltburn', 'Top Gun: Maverick', 'Godzilla x Kong: The New Empire', "National Lampoon's Christmas Vacation", 'Paprika', 'Family Switch', 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe', 'Inside Out 2', 'Ant-Man and the Wasp: Quantumania', 'Radical', 'A Christmas Carol', 'Ruby Gillman, Teenage Kraken', 'Harry Potter and the Goblet of Fire', 'Cobweb', 'Godzilla: King of the Monsters', 'Avatar', 'Harry Potter and the Order of the Phoenix', 'Harry Potter and the
02640629222085344), (2917, 0.026336136575048907), (12282, 0.02633367409256494), (5825, 0.026319910492369907), (10018, 0.025936766038637912), (9527, 0.02591825795015346), (777, 0.025866422676573513), (14165, 0.025805329789746888), (4606, 0.025576833809586724), (13880, 0.025399244610118124), (981, 0.025319100440980652), (13327, 0.025306670147961393), (7900, 0.025231984894864862), (9141, 0.02514790693393097), (484, 0.025131126435791223), (475, 0.025082065237039285), (2884, 0.024909185559201255), (388, 0.024796668927141663), (5106, 0.02477720462550184), (12126, 0.02474930219751517), (11621, 0.024739922668193894), (788, 0.024469604014987822), (13916, 0.02433042314315804), (6268, 0.024328965191970038), (812, 0.024198560691200233), (1916, 0.024102807918478714), (10076, 0.024088765608217075), (8390, 0.024081311439574066), (4996, 0.023699330876082156), (10679, 0.023684575590976278), (3496, 0.023643655953151915), (5358, 0.023615384223241727), (11960, 0.023577418355462766), (6548, 0.02343028164408647), (988, 0.023192373682304826), (10136, 0.023180890618808993), (11137, 0.023156545087564), (3871, 0.023146559248089716), (1910, 0.023093627380391626), (14127, 0.023000529045963093), (13506, 0.022996547222850803), (3379, 0.0229181789244672), (4878, 0.022885043990831595), (3559, 0.022837078096626724), (12732, 0.022735798913200312), (7824, 0.0227034789002005), (4104, 0.022632040801593867), (12291, 0.0226083984827009), (7864, 0.022553958669369985), (3563, 0.02255273770242671), (1251, 0.022498441913508544), (6463, 0.0223545638181631), (13124, 0.022294928518989177), (10087, 0.022233824668503984), (10269, 0.022175383665723854), (5761, 0.022079049470917902), (3213, 0.022064695699205158), (11959, 0.022040969298550595), (9961, 0.021943914658344825), (9903, 0.021936917627654397), (985, 0.02192034338875422), (4145, 0.021886684768246092), (14332, 0.0218756 ...

# %%
print('Movies suggested for you: \n')
i = 1
suggested_movies = []
for movie in sorted_similar_movies:

    index = movie[0]
    title_from_index = movies_data[movies_data.index==index]['Title'].values[0]
    
    if i < 21:
        if title_from_index not in suggested_movies:
            suggested_movies.append(title_from_index)
        print(i,'.',title_from_index)
        i = i + 1
# Out:
# Movies suggested for you:
#
# 1 . RRR
# 2 . Bāhubali: The Beginning
# 3 . K.G.F: Chapter 2
# 4 . The Rising Hawk
# 5 . Khufiya
# 6 . Baahubali: The Beginning
# 7 . Pushpa: The Rise - Part 1
# 8 . War
# 9 . Tiger 3
# 10 . Jai Lava Kusa
# 11 . Heart of Stone
# 12 . Kama Sutra: A Tale of Love
# 13 . Bāhubali 2: The Conclusion
# 14 . Dry Day
# 15 . दिल जो भी कहे
# 16 . Youth in Revolt
# 17 . Main Hoon Na
# 18 . Adipurush
# 19 . Indiana Jones and the Last Crusade
# 20 . The Indian Fighter

# %%
suggested_movies
# Out:
# ['RRR',
#  'Bāhubali: The Beginning',
#  'K.G.F: Chapter 2',
#  'The Rising Hawk',
#  'Khufiya',
#  'Baahubali: The Beginning',
#  'Pushpa: The Rise - Part 1',
#  'War',
#  'Tiger 3',
#  'Jai Lava Kusa',
#  'Heart of Stone',
#  'Kama Sutra: A Tale of Love',
#  'Bāhubali 2: The Conclusion',
#  'Dry Day',
#  'दिल जो भी कहे',
#  'Youth in Revolt',
#  'Main Hoon Na',
#  'Adipurush',
#  'Indiana Jones and the Last Crusade',
#  'The Indian Fighter']
